# %% [markdown]
# # Data Processing

# %%
import numpy as np
import pandas as pd
import datetime

# %% [markdown]
# About rank database
# - gives top 100 songs each week of each year from 1958 to 2019

# %% [markdown]
# ### Sampling the Songs
# create a new dataframe with our sample
# - sort the rows in rank dataframe based on their chronological weekID order
# - we want to use completed decades (60s, 70s, 80s, 90s, 00s)
# - pick the first five songs listed for each year (week rank 1-5)???
# - need to pick carefully, because songs could be in the same ranks each week and we dont want duplicates
# - so we could pick 5 random songs each year

# %%
# read into dataframes
features_df = pd.read_csv('Hot 100 Audio Features.csv')
ranks_df = pd.read_csv('Hot Stuff.csv')

# %%
features_df.head()
# Out:
#                                               SongID  \
# 0                      AdictoTainy, Anuel AA & Ozuna
# 1  The Ones That Didn't Make It Back HomeJustin M...
# 2                  ShallowLady Gaga & Bradley Cooper
# 3                EnemiesPost Malone Featuring DaBaby
# 4    Bacc At It AgainYella Beezy, Gucci Mane & Quavo
#
#                          Performer                                    Song  \
# 0          Tainy, Anuel AA & Ozuna                                  Adicto
# 1                     Justin Moore  The Ones That Didn't Make It Back Home
# 2       Lady Gaga & Bradley Cooper                                 Shallow
# 3     Post Malone Featuring DaBaby                                 Enemies
# 4  Yella Beezy, Gucci Mane & Quavo                        Bacc At It Again
#
#                                        spotify_genre        spotify_track_id  \
# 0                                  ['pop reggaeton']  3jbT1Y5MoPwEIpZndDDwVq
# 1  ['arkansas country', 'contemporary country', '...                     NaN
# 2                               ['dance pop', 'pop']  2VxeLyX666F8uXCJ0dZF8B
# 3                  ['dfw rap', 'melodic rap', 'rap']  0Xek5rqai2jcOWCYWJfVCF
# 4     ['dfw rap', 'rap', 'southern hip hop', 'trap']  2biNa12dMbHJrHVFRt8JyO
#
#                            spotify_track_preview_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  https://p.scdn.co/mp3-preview/fa6fa6f6f363be29...
#
#               spotify_track_album spotify_track_explicit  \
# 0  Adicto (with Anuel AA & Ozuna)                  False
# 1                             NaN                    NaN
# 2       A Star Is Born Soundtrack                  False
# 3            Hollywood's Bleeding                   True
# 4                Bacc At It Again                   True
#
#    spotify_track_duration_ms  spotify_track_popularity  ...   key  loudness  \
# 0                   270740.0                      91.0  ...  10.0    -4.803
# 1                        NaN                       NaN  ...   NaN       NaN
# 2                   215733.0                      88.0  ...   7.0    -6.362
# 3                   196760.0                      86.0  ...   6.0    -4.169
# 4                   228185.0                      61.0  ...   8.0    -5.725
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0   0.0       0.0735       0.01700          0.000016    0.1790    0.623
# 1   NaN          NaN           NaN               NaN       NaN      NaN
# 2   1.0       0.0308       0.37100          0.000000    0.2310    0.323
# 3   1.0       0.2100       0.05880          0.000000    0.0955    0.667
# 4   0.0       0.1680       0.00124          0.000001    0.0716    0.856
#
#      tempo  time_signature
# 0   80.002             4.0
# 1      NaN             NaN
# 2   95.799             4.0
# 3   76.388             4.0
# 4  135.979             4.0
#
# [5 rows x 22 columns]

# %%
ranks_df.head()
# Out:
#                                                  url      WeekID  \
# 0  http://www.billboard.com/charts/hot-100/1958-0...    8/2/1958
# 1  http://www.billboard.com/charts/hot-100/1995-1...   12/2/1995
# 2  http://www.billboard.com/charts/hot-100/1997-1...  10/11/1997
# 3  http://www.billboard.com/charts/hot-100/2006-0...    7/1/2006
# 4  http://www.billboard.com/charts/hot-100/2009-1...  10/24/2009
#
#    Week Position                                               Song  \
# 0              1                                   Poor Little Fool
# 1              1                                      One Sweet Day
# 2              1  Candle In The Wind 1997/Something About The Wa...
# 3              1                                Do I Make You Proud
# 4              1                                                  3
#
#                     Performer  \
# 0                Ricky Nelson
# 1  Mariah Carey & Boyz II Men
# 2                  Elton John
# 3                Taylor Hicks
# 4              Britney Spears
#
#                                               SongID  Instance  \
# 0                       Poor Little FoolRicky Nelson         1
# 1            One Sweet DayMariah Carey & Boyz II Men         1
# 2  Candle In The Wind 1997/Something About The Wa...         1
# 3                    Do I Make You ProudTaylor Hicks         1
# 4                                    3Britney Spears         1
#
#    Previous Week Position  Peak Position  Weeks on Chart
# 0                     NaN              1               1
# 1                     NaN              1               1
# 2                     NaN              1               1
# 3                     NaN              1               1
# 4                     NaN              1               1

# %%
features = features_df.copy(deep=True)
ranks = ranks_df.copy(deep=True)

# %%
# ranks preprocessing
dt = []
for row_index, row in ranks.iterrows():
    temp = datetime.datetime.strptime(ranks.at[row_index, 'WeekID'], '%m/%d/%Y')
    dt.append(temp)
ranks['Datetime'] = dt

# %%
ranks = ranks.sort_values(by=['Datetime', 'Week Position'])
ranks.head()
# Out:
#                                                       url    WeekID  \
# 0       http://www.billboard.com/charts/hot-100/1958-0...  8/2/1958
# 14      http://www.billboard.com/charts/hot-100/1958-0...  8/2/1958
# 29      http://www.billboard.com/charts/hot-100/1958-0...  8/2/1958
# 4795    http://www.billboard.com/charts/hot-100/1958-0...  8/2/1958
# 157577  http://www.billboard.com/charts/hot-100/1958-0...  8/2/1958
#
#         Week Position               Song                           Performer  \
# 0                   1   Poor Little Fool                        Ricky Nelson
# 14                  2           Patricia       Perez Prado And His Orchestra
# 29                  3      Splish Splash                         Bobby Darin
# 4795                4  Hard Headed Woman  Elvis Presley With The Jordanaires
# 157577              5               When                         Kalin Twins
#
#                                                    SongID  Instance  \
# 0                            Poor Little FoolRicky Nelson         1
# 14                  PatriciaPerez Prado And His Orchestra         1
# 29                               Splish SplashBobby Darin         1
# 4795    Hard Headed WomanElvis Presley With The Jordan...         1
# 157577                                    WhenKalin Twins         1
#
#         Previous Week Position  Peak Position  Weeks on Chart   Datetime
# 0                          NaN              1               1 1958-08-02
# 14                         NaN              2               1 1958-08-02
# 29                         NaN              3               1 1958-08-02
# 4795                       NaN              4               1 1958-08-02
# 157577                     NaN              5               1 1958-08-02

# %%
ranks_sample= ranks.copy(deep=True)
ranks_sample.reset_index(drop=True, inplace=True)

# %%
# remove decades that arent complete (50s, 2010s)

years_1 = np.arange(1958, 1960)
years_2 = np.arange(2011, 2020)
years_removed = np.concatenate((years_1, years_2), axis=None)

# this takes so freaking long to load 
#for row_index, row in ranks_sample.iterrows(): 
    #if row['Datetime'].year in years_removed:
        #ranks_sample = ranks_sample.drop(row_index)

# %%
bad_rows = []

for row_index, row in ranks_sample.iterrows(): 
    if row['Datetime'].year in years_removed:
        bad_rows.append(row_index)

# %%
ranks_sample.drop(ranks_sample.index[bad_rows], inplace=True)

# %%
ranks_sample.reset_index(drop=True, inplace=True)

# %%
ranks_sample
# Out:
#                                                       url      WeekID  \
# 0       http://www.billboard.com/charts/hot-100/1960-0...    1/2/1960
# 1       http://www.billboard.com/charts/hot-100/1960-0...    1/2/1960
# 2       http://www.billboard.com/charts/hot-100/1960-0...    1/2/1960
# 3       http://www.billboard.com/charts/hot-100/1960-0...    1/2/1960
# 4       http://www.billboard.com/charts/hot-100/1960-0...    1/2/1960
# ...                                                   ...         ...
# 266090  http://www.billboard.com/charts/hot-100/2010-1...  12/25/2010
# 266091  http://www.billboard.com/charts/hot-100/2010-1...  12/25/2010
# 266092  http://www.billboard.com/charts/hot-100/2010-1...  12/25/2010
# 266093  http://www.billboard.com/charts/hot-100/2010-1...  12/25/2010
# 266094  http://www.billboard.com/charts/hot-100/2010-1...  12/25/2010
#
#         Week Position                            Song  \
# 0                   1                         El Paso
# 1                   2                             Why
# 2                   3                    The Big Hurt
# 3                   4                    Running Bear
# 4                   5  Way Down Yonder In New Orleans
# ...               ...                             ...
# 266090             96                       September
# 266091             97                One In A Million
# 266092             98                       Marry You
# 266093             99               Porn Star Dancing
# 266094            100                        Bon, Bon
#
#                                    Performer  \
# 0                              Marty Robbins
# 1                             Frankie Avalon
# 2                           Miss Toni Fisher
# 3                             Johnny Preston
# 4                             Freddie Cannon
# ...                                      ...
# 266090                              Daughtry
# 266091                                 Ne-Yo
# 266092                            Bruno Mars
# 266093  My Darkest Days Featuring Zakk Wylde
# 266094                               Pitbull
#
#                                                    SongID  Instance  \
# 0                                    El PasoMarty Robbins         1
# 1                                       WhyFrankie Avalon         1
# 2                            The Big HurtMiss Toni Fisher         1
# 3                              Running BearJohnny Preston         2
# 4            Way Down Yonder In New OrleansFreddie Cannon         1
# ...                                                   ...       ...
# 266090                                  SeptemberDaughtry         1
# 266091                              One In A MillionNe-Yo         1
# 266092                                Marry YouBruno Mars         1
# 266093  Porn Star DancingMy Darkest Days Featuring Zak...         2
# 266094                                    Bon, BonPitbull         2
#
#         Previous Week Position  Peak Position  Weeks on Chart   Datetime
# 0                          2.0              1               9 1960-01-02
# 1                          1.0              1               7 1960-01-02
# 2                          3.0              3               8 1960-01-02
# 3                         11.0              4              12 1960-01-02
# 4                          5.0              5               7 1960-01-02
# ...                        ...            ...             ...        ...
# 266090                    85.0             36              19 2010-12-25
# 266091                    92.0             87               7 2010-12-25
# 266092                    90.0             90               3 2010-12-25
# 266093                     NaN             99               6 2010-12-25
# 266094                     NaN            100               5 2010-12-25
#
# [266095 rows x 11 columns]

# %% [markdown]
# <b> Now that we have the years cleaned up, we need to make sure the we only analyze songs that are in both the updaded ranks dataframe and the features dataframe </b>
#
# - merge them into one songs dataframe based on the songID column key

# %%
# merge ranks_sample and features dataframe into songs data frame
songs = pd.merge(ranks_sample, features, on='SongID', how='inner')

# %%
# clean up songs dataframe by removing columns we wont need 
cols_remove = ['Performer_y', 'Song_y', 'Weeks on Chart', 'Peak Position', 'Previous Week Position', 'Instance']
songs.drop(cols_remove, axis = 1, inplace=True)

songs.rename(columns={"Performer_x": "Performer", "Song_x": "Song"}, inplace=True)

songs
# Out:
#                                                       url      WeekID  \
# 0       http://www.billboard.com/charts/hot-100/1960-0...    1/2/1960
# 1       http://www.billboard.com/charts/hot-100/1960-0...    1/9/1960
# 2       http://www.billboard.com/charts/hot-100/1960-0...   1/16/1960
# 3       http://www.billboard.com/charts/hot-100/1960-0...   1/23/1960
# 4       http://www.billboard.com/charts/hot-100/1960-0...   1/30/1960
# ...                                                   ...         ...
# 265187  http://www.billboard.com/charts/hot-100/2010-1...  12/25/2010
# 265188  http://www.billboard.com/charts/hot-100/2010-1...  12/25/2010
# 265189  http://www.billboard.com/charts/hot-100/2010-1...  12/25/2010
# 265190  http://www.billboard.com/charts/hot-100/2010-1...  12/25/2010
# 265191  http://www.billboard.com/charts/hot-100/2010-1...  12/25/2010
#
#         Week Position                 Song                   Performer  \
# 0                   1              El Paso               Marty Robbins
# 1                   1              El Paso               Marty Robbins
# 2                   3              El Paso               Marty Robbins
# 3                   2              El Paso               Marty Robbins
# 4                   3              El Paso               Marty Robbins
# ...               ...                  ...                         ...
# 265187             59    Welcome Christmas                   Glee Cast
# 265188             68  Rolling In The Deep                       Adele
# 265189             89                No BS                 Chris Brown
# 265190             94        Bass Down Low  Dev Featuring The Cataracs
# 265191             95   Fall For Your Type  Jamie Foxx Featuring Drake
#
#                                               SongID   Datetime  \
# 0                               El PasoMarty Robbins 1960-01-02
# 1                               El PasoMarty Robbins 1960-01-09
# 2                               El PasoMarty Robbins 1960-01-16
# 3                               El PasoMarty Robbins 1960-01-23
# 4                               El PasoMarty Robbins 1960-01-30
# ...                                              ...        ...
# 265187                    Welcome ChristmasGlee Cast 2010-12-25
# 265188                      Rolling In The DeepAdele 2010-12-25
# 265189                              No BSChris Brown 2010-12-25
# 265190       Bass Down LowDev Featuring The Cataracs 2010-12-25
# 265191  Fall For Your TypeJamie Foxx Featuring Drake 2010-12-25
#
#                                             spotify_genre  \
# 0                   ['cowboy western', 'nashville sound']
# 1                   ['cowboy western', 'nashville sound']
# 2                   ['cowboy western', 'nashville sound']
# 3                   ['cowboy western', 'nashville sound']
# 4                   ['cowboy western', 'nashville sound']
# ...                                                   ...
# 265187        ['glee club', 'hollywood', 'post-teen pop']
# 265188                  ['british soul', 'pop', 'uk pop']
# 265189      ['dance pop', 'pop', 'pop rap', 'r&b', 'rap']
# 265190                        ['dance pop', 'electropop']
# 265191  ['dance pop', 'hip hop', 'hip pop', 'neo soul'...
#
#               spotify_track_id  \
# 0       4f8hBeMXMvssn6HtFAtblo
# 1       4f8hBeMXMvssn6HtFAtblo
# 2       4f8hBeMXMvssn6HtFAtblo
# 3       4f8hBeMXMvssn6HtFAtblo
# 4       4f8hBeMXMvssn6HtFAtblo
# ...                        ...
# 265187  453OW4naq3cgZlk9oaHCu9
# 265188  1CkvWZme3pRgbzaxZnTl5X
# 265189  6P3cUSAoT4EeMxVgWVdBra
# 265190  4Xf7EL8G6FRYwvJADl0nf4
# 265191  0hRPRbA2B1CYmGNhWhFjwF
#
#                                 spotify_track_preview_url  ...   key loudness  \
# 0       https://p.scdn.co/mp3-preview/0bde321c4359f861...  ...   2.0   -9.709
# 1       https://p.scdn.co/mp3-preview/0bde321c4359f861...  ...   2.0   -9.709
# 2       https://p.scdn.co/mp3-preview/0bde321c4359f861...  ...   2.0   -9.709
# 3       https://p.scdn.co/mp3-preview/0bde321c4359f861...  ...   2.0   -9.709
# 4       https://p.scdn.co/mp3-preview/0bde321c4359f861...  ...   2.0   -9.709
# ...                                                   ...  ...   ...      ...
# 265187  https://p.scdn.co/mp3-preview/802b81ffd968fcf2...  ...  11.0   -9.302
# 265188  https://p.scdn.co/mp3-preview/8c174ce25d94b502...  ...   8.0   -5.119
# 265189  https://p.scdn.co/mp3-preview/4b3158b2f9d396b8...  ...   1.0   -6.359
# 265190                                                NaN  ...   0.0   -8.022
# 265191  https://p.scdn.co/mp3-preview/a9448c497cfc61e0...  ...   1.0  -11.736
#
#         mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0        1.0       0.0300        0.8350          0.000029    0.1600   0.6910
# 1        1.0       0.0300        0.8350          0.000029    0.1600   0.6910
# 2        1.0       0.0300        0.8350          0.000029    0.1600   0.6910
# 3        1.0       0.0300        0.8350          0.000029    0.1600   0.6910
# 4        1.0       0.0300        0.8350          0.000029    0.1600   0.6910
# ...      ...          ...           ...               ...       ...      ...
# 265187   1.0       0.0297        0.9110          0.000000    0.2750   0.0819
# 265188   1.0       0.0294        0.1310          0.000000    0.0527   0.5220
# 265189   0.0       0.0567        0.1200          0.000000    0.1190   0.1060
# 265190   1.0       0.0628        0.0886          0.000000    0.0499   0.8340
# 265191   1.0       0.0827        0.3940          0.000003    0.1100   0.1930
#
#           tempo  time_signature
# 0       106.662             3.0
# 1       106.662             3.0
# 2       106.662             3.0
# 3       106.662             3.0
# 4       106.662             3.0
# ...         ...             ...
# 265187  110.822             4.0
# 265188  104.945             4.0
# 265189  172.171             4.0
# 265190  113.035             4.0
# 265191  136.866             4.0
#
# [265192 rows x 26 columns]

# %%
# lets remove rows with duplicate SongIDs just for funsies 
songs = songs.drop_duplicates(subset='SongID', keep="first")
songs.reset_index(drop=True, inplace=True)

# %%
songs
# Out:
#                                                      url      WeekID  \
# 0      http://www.billboard.com/charts/hot-100/1960-0...    1/2/1960
# 1      http://www.billboard.com/charts/hot-100/1960-0...    1/2/1960
# 2      http://www.billboard.com/charts/hot-100/1960-0...    1/2/1960
# 3      http://www.billboard.com/charts/hot-100/1960-0...    1/2/1960
# 4      http://www.billboard.com/charts/hot-100/1960-0...    1/2/1960
# ...                                                  ...         ...
# 23615  http://www.billboard.com/charts/hot-100/2010-1...  12/25/2010
# 23616  http://www.billboard.com/charts/hot-100/2010-1...  12/25/2010
# 23617  http://www.billboard.com/charts/hot-100/2010-1...  12/25/2010
# 23618  http://www.billboard.com/charts/hot-100/2010-1...  12/25/2010
# 23619  http://www.billboard.com/charts/hot-100/2010-1...  12/25/2010
#
#        Week Position                            Song  \
# 0                  1                         El Paso
# 1                  2                             Why
# 2                  3                    The Big Hurt
# 3                  4                    Running Bear
# 4                  5  Way Down Yonder In New Orleans
# ...              ...                             ...
# 23615             59               Welcome Christmas
# 23616             68             Rolling In The Deep
# 23617             89                           No BS
# 23618             94                   Bass Down Low
# 23619             95              Fall For Your Type
#
#                         Performer  \
# 0                   Marty Robbins
# 1                  Frankie Avalon
# 2                Miss Toni Fisher
# 3                  Johnny Preston
# 4                  Freddie Cannon
# ...                           ...
# 23615                   Glee Cast
# 23616                       Adele
# 23617                 Chris Brown
# 23618  Dev Featuring The Cataracs
# 23619  Jamie Foxx Featuring Drake
#
#                                              SongID   Datetime  \
# 0                              El PasoMarty Robbins 1960-01-02
# 1                                 WhyFrankie Avalon 1960-01-02
# 2                      The Big HurtMiss Toni Fisher 1960-01-02
# 3                        Running BearJohnny Preston 1960-01-02
# 4      Way Down Yonder In New OrleansFreddie Cannon 1960-01-02
# ...                                             ...        ...
# 23615                    Welcome ChristmasGlee Cast 2010-12-25
# 23616                      Rolling In The DeepAdele 2010-12-25
# 23617                              No BSChris Brown 2010-12-25
# 23618       Bass Down LowDev Featuring The Cataracs 2010-12-25
# 23619  Fall For Your TypeJamie Foxx Featuring Drake 2010-12-25
#
#                                            spotify_genre  \
# 0                  ['cowboy western', 'nashville sound']
# 1      ['adult standards', 'brill building pop', 'bub...
# 2                               ['deep adult standards']
# 3      ['brill building pop', 'deep adult standards',...
# 4                                                    NaN
# ...                                                  ...
# 23615        ['glee club', 'hollywood', 'post-teen pop']
# 23616                  ['british soul', 'pop', 'uk pop']
# 23617      ['dance pop', 'pop', 'pop rap', 'r&b', 'rap']
# 23618                        ['dance pop', 'electropop']
# 23619  ['dance pop', 'hip hop', 'hip pop', 'neo soul'...
#
#              spotify_track_id  \
# 0      4f8hBeMXMvssn6HtFAtblo
# 1      0CRxGsJrwOMQUuTr4yT5mX
# 2      37Au0ObjCx4KD76YBe4Y9g
# 3      1RYznli2VNO7FCbW1Hq4KM
# 4                         NaN
# ...                       ...
# 23615  453OW4naq3cgZlk9oaHCu9
# 23616  1CkvWZme3pRgbzaxZnTl5X
# 23617  6P3cUSAoT4EeMxVgWVdBra
# 23618  4Xf7EL8G6FRYwvJADl0nf4
# 23619  0hRPRbA2B1CYmGNhWhFjwF
#
#                                spotify_track_preview_url  ...   key loudness  \
# 0      https://p.scdn.co/mp3-preview/0bde321c4359f861...  ...   2.0   -9.709
# 1      https://p.scdn.co/mp3-preview/67736cba6b729941...  ...   5.0   -8.677
# 2      https://p.scdn.co/mp3-preview/fa1e0fcba1938041...  ...   0.0   -8.309
# 3      https://p.scdn.co/mp3-preview/2f892626e1b7c60a...  ...   5.0  -14.679
# 4                                                    NaN  ...   NaN      NaN
# ...                                                  ...  ...   ...      ...
# 23615  https://p.scdn.co/mp3-preview/802b81ffd968fcf2...  ...  11.0   -9.302
# 23616  https://p.scdn.co/mp3-preview/8c174ce25d94b502...  ...   8.0   -5.119
# 23617  https://p.scdn.co/mp3-preview/4b3158b2f9d396b8...  ...   1.0   -6.359
# 23618                                                NaN  ...   0.0   -8.022
# 23619  https://p.scdn.co/mp3-preview/a9448c497cfc61e0...  ...   1.0  -11.736
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0       1.0       0.0300        0.8350          0.000029    0.1600   0.6910
# 1       1.0       0.0264        0.7620          0.000000    0.1300   0.5860
# 2       1.0       0.0299        0.7830          0.000000    0.1730   0.6760
# 3       0.0       0.0530        0.8540          0.000008    0.1250   0.8220
# 4       NaN          NaN           NaN               NaN       NaN      NaN
# ...     ...          ...           ...               ...       ...      ...
# 23615   1.0       0.0297        0.9110          0.000000    0.2750   0.0819
# 23616   1.0       0.0294        0.1310          0.000000    0.0527   0.5220
# 23617   0.0       0.0567        0.1200          0.000000    0.1190   0.1060
# 23618   1.0       0.0628        0.0886          0.000000    0.0499   0.8340
# 23619   1.0       0.0827        0.3940          0.000003    0.1100   0.1930
#
#          tempo  time_signature
# 0      106.662             3.0
# 1       94.267             4.0
# 2      123.919             4.0
# 3      119.987             4.0
# 4          NaN             NaN
# ...        ...             ...
# 23615  110.822             4.0
# 23616  104.945             4.0
# 23617  172.171             4.0
# 23618  113.035             4.0
# 23619  136.866             4.0
#
# [23620 rows x 26 columns]

# %% [markdown]
# <b> Now, we want to pick 5 random songs from every year (250 total songs) </b>
# - im not sure how to do this, but for now lets look at the 1st 5 songs of every year (week position 1-5)
# - the only way I can think to do this is to make a separate dataframe for each year and then take a sample of that?   then merge? yikes!
# - downside to this: we will end up just examining the songs popular in january of every year :(
